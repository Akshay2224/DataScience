# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay2224/DataScience/blob/master/EDA_Statistics_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('https://github.com/Akshay2224/DataScience/blob/master/EDA_nas.csv?raw=true')

# %%
df.head()
# Out:
#          STUID        State  District  ... Reading.. Science..  Social..
# 0  26011001001  Maharashtra         1  ...     33.33       NaN       NaN
# 1  26011001002  Maharashtra         1  ...     62.07       NaN       NaN
# 2  26011001003  Maharashtra         1  ...     41.38       NaN       NaN
# 3  26011001004  Maharashtra         1  ...       NaN       NaN       NaN
# 4  26011001005  Maharashtra         1  ...       NaN     27.27       NaN
#
# [5 rows x 64 columns]

# %%
df.query('Age=="12 years"')
# Out:
#             STUID        State  District  ... Reading.. Science..  Social..
# 24    26011002005  Maharashtra         1  ...       NaN     27.27       NaN
# 145   26011006016  Maharashtra         1  ...     73.33       NaN       NaN
# 194   26011007025  Maharashtra         1  ...     60.00       NaN       NaN
# 411   26011016024  Maharashtra         1  ...       NaN       NaN     51.02
# 429   26011017002  Maharashtra         1  ...     72.41     38.18       NaN
# 434   26011017007  Maharashtra         1  ...       NaN       NaN     40.82
# 468   26011018001  Maharashtra         1  ...     46.67       NaN       NaN
# 472   26011018005  Maharashtra         1  ...     40.00       NaN       NaN
# 474   26011018007  Maharashtra         1  ...     86.21       NaN     20.41
# 477   26011018010  Maharashtra         1  ...       NaN     49.09     69.39
# 482   26011018015  Maharashtra         1  ...     48.28       NaN       NaN
# ...

# %%
df.shape
# Out:
# (8801, 64)

# %%
df['Maths'].mean
# Out:
# Index(['STUID', 'State', 'District', 'Gender', 'Age', 'Category',
#        'Same.language', 'Siblings', 'Handicap', 'Father.edu', 'Mother.edu',
#        'Father.occupation', 'Mother.occupation', 'Below.poverty',
#        'Use.calculator', 'Use.computer', 'Use.Internet', 'Use.dictionary',
#        'Read.other.books', 'X..Books', 'Distance', 'Computer.use',
#        'Library.use', 'Like.school', 'Subjects', 'Give.Lang.HW',
#        'Give.Math.HW', 'Give.Scie.HW', 'Give.SoSc.HW', 'Correct.Lang.HW',
#        'Correct.Math.HW', 'Correct.Scie.HW', 'Correct.SocS.HW',
#        'Help.in.Study', 'Private.tuition', 'English.is.difficult',
#        'Read.English', 'Dictionary.to.learn', 'Answer.English.WB',
#        'Answer.English.aloud', 'Maths.is.difficult', 'Solve.Maths',
#        'Solve.Maths.in.groups', 'Draw.geometry', 'Explain.answers',
#        'SocSci.is.difficult', 'Historical.excursions', 'Participate.in.SocSci',
#        'Small.groups.in.SocSci', 'Express.SocSci.views',
# ...

# %%
p=df[['Maths..']].groupby(df['Solve.Maths']).mean()

# %%
p
# Out:
#                Maths..
# Solve.Maths
# Agree        32.800920
# Disagree     30.841321
# Neither      29.384388

# %% [markdown]
# ### Here we can see that there is not much diffrence in the mean marks of student in maths who solve maths problems or not

# %%
df1=pd.read_csv('https://github.com/Akshay2224/DataScience/raw/master/EDA_Gold_Silver_prices.csv')

# %%
df1.head()
# Out:
#     Month  SilverPrice  GoldPrice
# 0  Mar-97       186.48   12619.24
# 1  Apr-97       170.65   12338.59
# 2  May-97       170.44   12314.94
# 3  Jun-97       169.96   12202.78
# 4  Jul-97       155.80   11582.07

# %%
from datetime import datetime
df1['Year']=df1['Month'].apply(lambda x:x[4:])
df1['SilverPrice']=df1['SilverPrice'].round(2)
df1['GoldPrice']=df1['GoldPrice'].round(2)

# %%
sns.scatterplot(x='GoldPrice',y='SilverPrice',data=df1)

# %%
df1.corr()
# Out:
#              SilverPrice  GoldPrice
# SilverPrice     1.000000   0.954256
# GoldPrice       0.954256   1.000000

# %%
df1.head()
# Out:
#     Month  SilverPrice  GoldPrice Year
# 0  Mar-97       186.48   12619.24   97
# 1  Apr-97       170.65   12338.59   97
# 2  May-97       170.44   12314.94   97
# 3  Jun-97       169.96   12202.78   97
# 4  Jul-97       155.80   11582.07   97

# %%
df2=df1.query('Year=="08"')

# %%
df2.corr().round(2)
# Out:
#              SilverPrice  GoldPrice
# SilverPrice         1.00       0.01
# GoldPrice           0.01       1.00

# %% [markdown]
# ### We can see in average there is high correlation between the prices of silver and Gold in India

# %%
df2=pd.read_csv('https://github.com/Akshay2224/DataScience/raw/master/currencies.csv')

# %%
df2.columns
# Out:
# Index(['Currency', 'Chinese Yuan', 'Euro', 'Japanese Yen',
#        'U.K. Pound Sterling', 'U.S. Dollar', 'Algerian Dinar',
#        'Australian Dollar', 'Bahrain Dinar', 'Botswana Pula', 'Brazilian Real',
#        'Brunei Dollar', 'Canadian Dollar', 'Chilean Peso', 'Colombian Peso',
#        'Czech Koruna', 'Danish Krone', 'Hungarian Forint', 'Icelandic Krona',
#        'Indian Rupee', 'Indonesian Rupiah', 'Iranian Rial',
#        'Israeli New Sheqel', 'Kazakhstani Tenge', 'Korean Won',
#        'Kuwaiti Dinar', 'Libyan Dinar', 'Malaysian Ringgit', 'Mauritian Rupee',
#        'Mexican Peso', 'Nepalese Rupee', 'New Zealand Dollar',
#        'Norwegian Krone', 'Rial Omani', 'Pakistani Rupee', 'Nuevo Sol',
#        'Philippine Peso', 'Polish Zloty', 'Qatar Riyal', 'Russian Ruble',
#        'Saudi Arabian Riyal', 'Singapore Dollar', 'South African Rand',
#        'Sri Lanka Rupee', 'Swedish Krona', 'Swiss Franc', 'Thai Baht',
# ...

# %%
df2.head()
# Out:
#         Currency  Chinese Yuan  ...  Peso Uruguayo  Bolivar Fuerte
# 0  July 01, 2016       9.29446  ...            NaN         13.9247
# 1  July 05, 2016       9.31515  ...        42.9026         13.9335
# 2  July 06, 2016       9.31697  ...        42.6425         13.8938
# 3  July 07, 2016       9.31315  ...        42.4176         13.8968
# 4  July 08, 2016       9.31350  ...        42.2060         13.8909
#
# [5 rows x 52 columns]

# %%
p=df2.corr()
p['Indian Rupee'].sort_values()
# Out:
# Swiss Franc                  -6.558659e-01
# Tunisian Dinar               -6.180409e-01
# Japanese Yen                 -2.701235e-01
# Swedish Krona                -1.869909e-01
# Trinidad And Tobago Dollar   -1.868609e-01
# Kazakhstani Tenge            -7.479939e-02
# Philippine Peso              -5.744519e-02
# Brazilian Real               -5.647548e-02
# Norwegian Krone              -1.968181e-02
# Libyan Dinar                 -3.980360e-15
# Euro                          2.438507e-01
# Danish Krone                  2.824453e-01
# Chinese Yuan                  3.040500e-01
# Canadian Dollar               3.042907e-01
# U.K. Pound Sterling           3.146806e-01
# New Zealand Dollar            4.446350e-01
# Polish Zloty                  4.747921e-01
# Israeli New Sheqel            5.181957e-01
# Czech Koruna                  6.119937e-01
# Mexican Peso                  6.570359e-01
# Chilean Peso                  7.510848e-01
# Hungarian Forint              7.546882e-01
# ...

# %% [markdown]
# ###These shows indian currency has highest correlation with pakistani rupee.

# %%
p['Japanese Yen'].sort_values()
# Out:
# U.K. Pound Sterling          -0.970308
# Icelandic Krona              -0.834549
# Norwegian Krone              -0.818583
# Chilean Peso                 -0.809751
# Polish Zloty                 -0.806694
# Israeli New Sheqel           -0.798265
# Russian Ruble                -0.774645
# Danish Krone                 -0.668736
# Canadian Dollar              -0.662233
# Euro                         -0.645719
# Brazilian Real               -0.641122
# South African Rand           -0.629790
# Czech Koruna                 -0.629068
# Botswana Pula                -0.627015
# Malaysian Ringgit            -0.602250
# Nepalese Rupee               -0.602069
# Australian Dollar            -0.582032
# Hungarian Forint             -0.572344
# Peso Uruguayo                -0.513065
# Mexican Peso                 -0.497609
# Swedish Krona                -0.484786
# Thai Baht                    -0.458043
# Algerian Dinar               -0.388099
# Indian Rupee                 -0.270123
# ...

# %% [markdown]
# ####Here Japanese yen has positive Correlation U.S Dollar so we will not take it.

# %%
p['Australian Dollar'].sort_values()
# Out:
# Tunisian Dinar               -0.677335
# Swiss Franc                  -0.651600
# Japanese Yen                 -0.582032
# Trinidad And Tobago Dollar   -0.504815
# Pakistani Rupee              -0.250614
# Philippine Peso              -0.158866
# Swedish Krona                -0.067537
# Kazakhstani Tenge             0.005796
# Brazilian Real                0.071958
# Chinese Yuan                  0.077983
# Norwegian Krone               0.155883
# Euro                          0.331588
# Danish Krone                  0.369431
# Canadian Dollar               0.422272
# New Zealand Dollar            0.429160
# Nuevo Sol                     0.529584
# Czech Koruna                  0.532192
# Mexican Peso                  0.573500
# U.K. Pound Sterling           0.579213
# Polish Zloty                  0.592071
# Israeli New Sheqel            0.602386
# U.S. Dollar                   0.607010
# U.A.E. Dirham                 0.607053
# Bolivar Fuerte                0.607077
# ...

# %% [markdown]
# ####Here Austarlian Dollar has positive Correlation with INR so we will not take it.

# %%
p['Japanese Yen'].sort_values()
# Out:
# U.K. Pound Sterling          -0.970308
# Icelandic Krona              -0.834549
# Norwegian Krone              -0.818583
# Chilean Peso                 -0.809751
# Polish Zloty                 -0.806694
# Israeli New Sheqel           -0.798265
# Russian Ruble                -0.774645
# Danish Krone                 -0.668736
# Canadian Dollar              -0.662233
# Euro                         -0.645719
# Brazilian Real               -0.641122
# South African Rand           -0.629790
# Czech Koruna                 -0.629068
# Botswana Pula                -0.627015
# Malaysian Ringgit            -0.602250
# Nepalese Rupee               -0.602069
# Australian Dollar            -0.582032
# Hungarian Forint             -0.572344
# Peso Uruguayo                -0.513065
# Mexican Peso                 -0.497609
# Swedish Krona                -0.484786
# Thai Baht                    -0.458043
# Algerian Dinar               -0.388099
# Indian Rupee                 -0.270123
# ...

# %% [markdown]
# ####Here Japanese Yen  has negative Correlation with U.K pound Sterling so we will  take it.

# %%
p['Chinese Yuan'].sort_values()
# Out:
# Kazakhstani Tenge            -0.349278
# Canadian Dollar              -0.186643
# Icelandic Krona              -0.094406
# Swiss Franc                  -0.069368
# Nepalese Rupee               -0.048039
# Swedish Krona                -0.044773
# Czech Koruna                 -0.000742
# Norwegian Krone               0.011336
# Chilean Peso                  0.028821
# Kuwaiti Dinar                 0.051050
# Australian Dollar             0.077983
# Hungarian Forint              0.092517
# U.K. Pound Sterling           0.108695
# Japanese Yen                  0.117566
# Euro                          0.151596
# New Zealand Dollar            0.158424
# Philippine Peso               0.161906
# Russian Ruble                 0.184050
# Danish Krone                  0.190088
# Trinidad And Tobago Dollar    0.215925
# Malaysian Ringgit             0.235758
# Mauritian Rupee               0.273543
# Saudi Arabian Riyal           0.291155
# U.A.E. Dirham                 0.291300
# ...

# %% [markdown]
# ####Here Chinese Yuan  has positive Correlation with Euro so we will not take it.

# %% [markdown]
# ###Answer is Japanese yuan and U.K Pound Sterling

# %%
import pandas as pd
cust_rating = pd.read_csv('https://query.data.world/s/ILc-P4llUraMaYN6N6Bdw7p6kUvHnj')

# %%
cust_rating.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
cust_rating['avg_rating'] =round((cust_rating['rating']+cust_rating['food_rating']+cust_rating['service_rating'])/3)

print(cust_rating.head(10))
# Out:
#   userID  placeID  rating  food_rating  service_rating  avg_rating
# 0  U1077   135085       2            2               2         2.0
# 1  U1077   135038       2            2               1         2.0
# 2  U1077   132825       2            2               2         2.0
# 3  U1077   135060       1            2               2         2.0
# 4  U1068   135104       1            1               2         1.0
# 5  U1068   132740       0            0               0         0.0
# 6  U1068   132663       1            1               1         1.0
# 7  U1068   132732       0            0               0         0.0
# 8  U1068   132630       1            1               1         1.0
# 9  U1067   132584       2            2               2         2.0

# %% [markdown]
# ####Here are some average rating got from users

# %%
df4=pd.read_csv('https://github.com/Akshay2224/DataScience/blob/master/odi-batting.csv?raw=true')

# %%
df4.head()
# Out:
#        Country            Player  ...       Versus Balls
# 0  Afghanistan  Mohammad Shahzad  ...       Canada   121
# 1  Afghanistan  Mohammad Shahzad  ...  Netherlands   111
# 2  Afghanistan  Mohammad Shahzad  ...     Scotland    72
# 3  Afghanistan  Mohammad Shahzad  ...  Netherlands   108
# 4  Afghanistan  Mohammad Shahzad  ...       Canada    57
#
# [5 rows x 8 columns]

# %%
p=df4.query('Runs>=100')

# %%
p['Strike Rate']=(p['Runs']/p['Balls'])*100
p.sort_values('Strike Rate',ascending=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#             Country                     Player  ...  Balls Strike Rate
# 28157      Pakistan              Shahid Afridi  ...     40  255.000000
# 28158      Pakistan              Shahid Afridi  ...     46  221.739130
# 34446  South Africa             Mark V Boucher  ...     68  216.176471
# 28153      Pakistan              Shahid Afridi  ...     60  206.666667
# 36753     Sri Lanka        Sanath T Jayasuriya  ...     65  206.153846
# 2872      Australia             Shane R Watson  ...     96  192.708333
# 41927   West Indies               Brian C Lara  ...     62  188.709677
# ...

# %%
p.groupby('Player').count().sort_values('Runs',ascending=False)
# Out:
#                            Country  Runs  MatchDate  ...  Ground  Versus  Balls
# Player                                               ...
# Sachin R Tendulkar              48    48         48  ...      48      48     48
# Ricky T Ponting                 30    30         30  ...      30      30     30
# Sanath T Jayasuriya             28    28         28  ...      28      28     28
# Sourav C Ganguly                22    22         22  ...      22      22     22
# Herschelle H Gibbs              21    21         21  ...      21      21     21
# Saeed Anwar                     20    20         20  ...      20      20     20
# Christopher H Gayle             19    19         19  ...      19      19     19
# Brian C Lara                    19    19         19  ...      19      19     19
# Mark E Waugh                    18    18         18  ...      18      18     18
# Desmond L Haynes                17    17         17  ...      17      17     17
# ...

# %%
df4.sort_values('Strike Rate',ascending=False)
# Out:
#                     Country                   Player  ...  Balls Strike Rate
# 18203                 India           Yusuf K Pathan  ...      1    6.000000
# 29715              Pakistan              Wasim Akram  ...      1    6.000000
# 32185              Pakistan              Aaqib Javed  ...      1    6.000000
# 18988                 India  Bapu K Venkatesh Prasad  ...      1    6.000000
# 26429           New Zealand        Daniel K Morrison  ...      2    5.000000
# 45864           West Indies             Ian R Bishop  ...      3    4.666667
# 3703              Australia            James R Hopes  ...      3    4.000000
# 4473              Australia            George B Hogg  ...      1    4.000000
# 4095              Australia            Shane K Warne  ...      1    4.000000
# 32400              Pakistan               Akram Raza  ...      1    4.000000
# 28393              Pakistan            Shahid Afridi  ...      1    4.000000
# ...

# %%
p
# Out:
#            Country                 Player  ...  Balls Strike Rate
# 0      Afghanistan       Mohammad Shahzad  ...    121   97.520661
# 1      Afghanistan       Mohammad Shahzad  ...    111   99.099099
# 2      Afghanistan       Mohammad Shahzad  ...     72  138.888889
# 62     Afghanistan        Noor Ali Zadran  ...    127   89.763780
# 87     Afghanistan           Karim Sadiq   ...    108  105.555556
# 138      Australia        Ricky T Ponting  ...    105  156.190476
# 139      Australia        Ricky T Ponting  ...    158   91.772152
# 140      Australia        Ricky T Ponting  ...    127  111.023622
# 141      Australia        Ricky T Ponting  ...    121  115.702479
# 142      Australia        Ricky T Ponting  ...    133  100.751880
# 143      Australia        Ricky T Ponting  ...    126  102.380952
# 144      Australia        Ricky T Ponting  ...    109  115.596330
# 145      Australia        Ricky T Ponting  ...    129   96.124031
# ...

# %%
from datetime import datetime

# %%
p['Year']=pd.DatetimeIndex(p['MatchDate']).year
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
l=p.query('Runs>100 & Country=="India"')
l.groupby('Year')['Runs'].count()
# Out:
# Year
# 1983     1
# 1984     3
# 1986     2
# 1987     4
# 1988     4
# 1989     2
# 1990     3
# 1991     2
# 1992     1
# 1993     1
# 1994     7
# 1995     1
# 1996     7
# 1997     6
# 1998    15
# 1999    14
# 2000     9
# 2001     7
# 2002     9
# 2003     9
# 2004     7
# 2005    11
# 2006     4
# 2007     4
# 2008    10
# 2009    13
# 2010    12
# 2011     7
# Name: Runs, dtype: int64

# %% [markdown]
# ####India scored maximum hundred in the year 1998

# %%
import pandas as pd
order = pd.read_csv('https://query.data.world/s/3hIAtsCE7vYkPEL-O5DyWJAeS5Af-7')
order['Order_Date'] = pd.to_datetime(order['Order_Date'])

# %%
p=order['Order_Date'].dt.day

# %%
p
# Out:
# 0       13
# 1       10
# 2        7
# 3       28
# 4       17
# 5       24
# 6       26
# 7       23
# 8        6
# 9        8
# 10      30
# 11      25
# 12      14
# 13      15
# 14       3
# 15       3
# 16       8
# 17       5
# 18      23
# 19      11
# 20      21
# 21       1
# 22      10
# 23      23
# 24      19
# 25      10
# 26      12
# 27      10
# 28       5
# 29       3
#         ..
# 5476    31
# 5477    16
# 5478     1
# 5479    23
# 5480    30
# 5481     4
# 5482     5
# 5483    26
# 5484     7
# 5485     7
# 5486     3
# 5487     1
# 5488    11
# 5489     6
# 5490     9
# 5491    29
# 5492    20
# 5493     7
# 5494    16
# 5495     2
# 5496    28
# 5497    26
# 5498     5
# 5499    11
# 5500    15
# 5501    10
# 5502     7
# 5503    30
# 5504     8
# 5505     2
# Name: Order_Date, Length: 5506, dtype: int64

# %% [markdown]
# ####Here we got the date from each row
